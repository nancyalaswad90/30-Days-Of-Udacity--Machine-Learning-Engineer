# %% [markdown]
# <a href="https://www.kaggle.com/code/nancyalaswad90/anaconda-ideas-work-in-diabetes-database?scriptVersionId=95027471" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Anaconda Work
#
# ====================
#
# **This notebood for my steps in Anaconda Work**

# %% [markdown]
# ![158026166-c97c4b00-65e7-48df-b7f3-4ddf1b5b97cf.png](attachment:53255989-4573-47fe-8fdc-cd9598506877.png)

# %% [markdown]
# # What is Anaconda Navigator?
#
# ==========================
#
#
# **Anaconda Navigator** is a desktop graphical user interface **(GUI)** included in Anaconda® distribution that allows you to launch applications and easily manage conda packages, environments, and channels without using command-line commands. Navigator can search for packages on Anaconda.org or in a local Anaconda Repository. It is available for `Windows`, `macOS` , and `Linux`.
#
# .
#
# > **These ideas published by [Anaconda-Starter-Guide](file:///C:/Users/USER/Downloads/Anaconda-Starter-Guide.pdf)**

# %%
from IPython.display import YouTubeVideo

# %%
YouTubeVideo('0jSIbdPLuTA', width=900 , height=350)

# %% [markdown]
# * > **My gathering data for video and slide ideas still in progress**

# %% [markdown]
# ### This Study notebook will explain ideas about useing the following software and Python libraries:
#
# * Python
# * NumPy
# * pandas
# * scikit-learn (v0.17)
# * Matplotlib
# * I will also need to execute a Jupyter Notebook.
#
# > **Thats why I recommended that you  to install the Anaconda distribution of Python, which already has the above packages and more included.**

# %%
print("سيشرح دفتر الدراسة هذا أفكارًا حول استخدام البرامج ومكتبات Python التالية:")
# Out:
# سيشرح دفتر الدراسة هذا أفكارًا حول استخدام البرامج ومكتبات Python التالية:

# %% [markdown]
# ![2022-03-18_041114.png](attachment:aff0d98e-a1b4-4abb-9689-6872b176f31d.png)

# %%
print("still in process to use it with many ideas as")
# Out:
# still in process to use it with many ideas as

# %% [markdown]
# > ## The work here about [Pima Indians Diabetes Database](https://www.kaggle.com/datasets/nancyalaswad90/review)

# %% [markdown]
# ### Introduction for data set content:
#
# This dataset is originally from the National Institute of Diabetes and Digestive and Kidney
# Diseases. The objective of the dataset is to diagnostically predict whether a patient has diabetes,
# based on certain diagnostic measurements included in the dataset. Several constraints were placed
# on the selection of these instances from a larger database. In particular, all patients here are females
# at least 21 years old of Pima Indian heritage.
#
#
# From the data set in the (.csv) File We can find several variables, some of them are independent
# (several medical predictor variables) and only one target dependent variable (Outcome).
#
#
#
# > **So I think the proper way to describe our dataset maybe from its rows (768 observations) and its
# columns (9 attributes) as below:**
